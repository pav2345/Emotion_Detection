# %% [markdown]
# <a href="https://colab.research.google.com/github/pav2345/Emotion_Detection/blob/main/Emotion_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install deepface

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

img1=cv2.imread('happy.jpeg')
plt.imshow(img1)
plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB))

#predicting emotions-happy
predictions=DeepFace.analyze(img1)

print(predictions)

#detecting faces
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +
                                     'haarcascade_frontalface_default.xml')

gray_img=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)

faces=face_cascade.detectMultiScale(gray_img,scaleFactor=1.12,minNeighbors=5)

for x,y,w,h in faces:
    img=cv2.rectangle(gray_img,(x,y),(x+w,y+h),(255,255,0),4)
font=cv2.FONT_HERSHEY_SIMPLEX
emotion_prediction = predictions[0]['dominant_emotion']
cv2.putText(img1, emotion_prediction, (0, 50), font, 1, (0, 0, 255), 2, cv2.LINE_4)


plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB))
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.85it/s]
# [{'emotion': {'angry': 4.872586844640106e-12, 'disgust': 6.612250723165271e-17, 'fear': 3.223287470266456e-08, 'happy': 99.99948740005493, 'sad': 1.2269823379540412e-06, 'surprise': 2.1412872863724175e-08, 'neutral': 0.0005177235834707972}, 'dominant_emotion': 'happy', 'region': {'x': 106, 'y': 44, 'w': 58, 'h': 58}, 'face_confidence': 6.11505605786806, 'age': 21, 'gender': {'Woman': 22.548013925552368, 'Man': 77.45198607444763}, 'dominant_gender': 'Man', 'race': {'asian': 12.789510952801166, 'indian': 16.460899499708383, 'black': 6.459328172166835, 'white': 4.256745309039671, 'middle eastern': 2.022023619533993, 'latino hispanic': 58.01149356433711}, 'dominant_race': 'latino hispanic'}]

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

img1=cv2.imread('sad.jpg')
plt.imshow(img1)
plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB))

#predicting emotions-happy
predictions=DeepFace.analyze(img1)

print(predictions)

#detecting faces
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +
                                     'haarcascade_frontalface_default.xml')

gray_img=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)

faces=face_cascade.detectMultiScale(gray_img,scaleFactor=1.12,minNeighbors=5)

for x,y,w,h in faces:
    img=cv2.rectangle(gray_img,(x,y),(x+w,y+h),(255,255,0),4)
font=cv2.FONT_HERSHEY_SIMPLEX
emotion_prediction = predictions[0]['dominant_emotion']
cv2.putText(img1, emotion_prediction, (0, 50), font, 1, (0, 0, 255), 2, cv2.LINE_4)


plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB))
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.76it/s]
# [{'emotion': {'angry': 0.024585609207861125, 'disgust': 2.5670316983195107e-07, 'fear': 1.9838862121105194, 'happy': 2.5970211936510168e-05, 'sad': 96.22833728790283, 'surprise': 4.245067075636655e-08, 'neutral': 1.7631689086556435}, 'dominant_emotion': 'sad', 'region': {'x': 294, 'y': 51, 'w': 561, 'h': 561}, 'face_confidence': 7.31733315665042, 'age': 25, 'gender': {'Woman': 99.84833598136902, 'Man': 0.15166866360232234}, 'dominant_gender': 'Woman', 'race': {'asian': 2.7840616181492805, 'indian': 9.913887828588486, 'black': 1.9935695454478264, 'white': 30.44929802417755, 'middle eastern': 21.11324667930603, 'latino hispanic': 33.745935559272766}, 'dominant_race': 'latino hispanic'}]

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

img1=cv2.imread('fear.jpeg')
plt.imshow(img1)
plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB))

#predicting emotions-happy
predictions=DeepFace.analyze(img1)

print(predictions)

#detecting faces
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +
                                     'haarcascade_frontalface_default.xml')

gray_img=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)

faces=face_cascade.detectMultiScale(gray_img,scaleFactor=1.12,minNeighbors=5)

for x,y,w,h in faces:
    img=cv2.rectangle(gray_img,(x,y),(x+w,y+h),(255,255,0),4)
font=cv2.FONT_HERSHEY_SIMPLEX
emotion_prediction = predictions[0]['dominant_emotion']
cv2.putText(img1, emotion_prediction, (0, 50), font, 1, (0, 0, 255), 2, cv2.LINE_4)


plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB))
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.16it/s]
# [{'emotion': {'angry': 0.0030818977393209934, 'disgust': 1.4500692660851717e-13, 'fear': 99.96021389961243, 'happy': 0.027945934562012553, 'sad': 0.00022797889869252685, 'surprise': 0.008526679448550567, 'neutral': 7.614947084358392e-11}, 'dominant_emotion': 'fear', 'region': {'x': 83, 'y': 38, 'w': 58, 'h': 58}, 'face_confidence': 9.752469998726156, 'age': 39, 'gender': {'Woman': 0.3136391984298825, 'Man': 99.6863603591919}, 'dominant_gender': 'Man', 'race': {'asian': 0.12242362136021256, 'indian': 46.41025960445404, 'black': 0.13717759866267443, 'white': 6.851567327976227, 'middle eastern': 25.105857849121094, 'latino hispanic': 21.37271612882614}, 'dominant_race': 'indian'}]

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace

img1=cv2.imread('surprise.jpeg')
plt.imshow(img1)
plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB))

#predicting emotions-happy
predictions=DeepFace.analyze(img1)

print(predictions)

#detecting faces
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +
                                     'haarcascade_frontalface_default.xml')

gray_img=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)

faces=face_cascade.detectMultiScale(gray_img,scaleFactor=1.12,minNeighbors=5)

for x,y,w,h in faces:
    img=cv2.rectangle(gray_img,(x,y),(x+w,y+h),(255,255,0),4)
font=cv2.FONT_HERSHEY_SIMPLEX
emotion_prediction = predictions[0]['dominant_emotion']
cv2.putText(img1, emotion_prediction, (0, 50), font, 1, (0, 0, 255), 2, cv2.LINE_4)


plt.imshow(cv2.cvtColor(img1,cv2.COLOR_BGR2RGB))
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.62it/s]
# [{'emotion': {'angry': 4.6047596291565185e-09, 'disgust': 9.498749637977615e-20, 'fear': 0.005697242158930749, 'happy': 2.8384486427945887e-08, 'sad': 1.5251688800788088e-11, 'surprise': 99.99430179595947, 'neutral': 8.408575476732245e-16}, 'dominant_emotion': 'surprise', 'region': {'x': 83, 'y': 28, 'w': 64, 'h': 64}, 'face_confidence': 5.0268410766730085, 'age': 30, 'gender': {'Woman': 15.223842859268188, 'Man': 84.77616310119629}, 'dominant_gender': 'Man', 'race': {'asian': 18.735789505933464, 'indian': 2.3069987961052414, 'black': 1.0281912345518154, 'white': 49.39792745088666, 'middle eastern': 9.369632973627207, 'latino hispanic': 19.16146804827071}, 'dominant_race': 'white'}]
